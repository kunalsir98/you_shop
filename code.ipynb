# %%
import os
print(os.getenv('MYSQL_HOST'))
print(os.getenv('MYSQL_USER'))
print(os.getenv('MYSQL_PASSWORD'))
print(os.getenv('MYSQL_DB'))
# Out:
# localhost
# root
# ##kc@##hc@98  # Your MySQL password
# promotions_db
